# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan-sadeghyan/IR-system/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.11.12

# %%
# !pip install torch torch-geometric dgl networkx matplotlib scikit-learn
# Out:
# ...
#   Using cached torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
# ...
# Using cached torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 75.5 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/afofanah/EATSA-GNN.git
# Out:
# Cloning into 'EATSA-GNN'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 33 (delta 14), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 1.35 MiB | 3.75 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
from sklearn.metrics import roc_curve, auc

# %%
# %run EATSA_Model.ipynb
# Out:
# ...
# Dataset: Cora():
# ...
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# Number of nodes: 2708
# Number of edges: 10556
# Number of features: 1433
# 1433
# Number of edge features: 0
# Number of classes: 7
# {np.int64(3): 818, np.int64(4): 426, np.int64(0): 351, np.int64(2): 418, np.int64(1): 217, np.int64(5): 298, np.int64(6): 180}
# label: 0
# 1527 edges
# {np.int64(0): 1068, np.int64(3): 161, np.int64(5): 75, np.int64(4): 88, np.int64(1): 32, np.int64(6): 80, np.int64(2): 23}
# label: 1
# 1029 edges
# {np.int64(0): 32, np.int64(1): 818, np.int64(2): 62, np.int64(6): 2, np.int64(5): 28, np.int64(3): 67, np.int64(4): 20}
# label: 2
# 1826 edges
# {np.int64(3): 53, np.int64(2): 1654, np.int64(5): 30, np.int64(0): 23, np.int64(1): 62, np.int64(4): 2, np.int64(6): 2}
# label: 3
# 2838 edges
# ...

# %%
# %cd EATSA-GNN
# Out:
# /content/EATSA-GNN

# %%
# !ls
# Out:
# data			       EATSA_Model.ipynb
# EAFE_Architecture.pdf	       graphsr.py
# EATSA_GNN_Visualization.ipynb  Overall_Architecture.pdf
# eatsa_gnn_visualization.py     README.md
# EATSA_ModelChamelon.ipynb
